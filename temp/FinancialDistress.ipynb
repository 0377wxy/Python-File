# %% [markdown]
# This project is to predict if a company will be under a financial distress in the future. The dataset was obtained from Kaggle dataset (https://www.kaggle.com/shebrahimi/financial-distress). Please see the page for the detailed description of the data.
#
# The stakeholder's requirement is to predict categorically (financially health/financially distressed), however, this categorical prediction is derived from a numerical data: if the variable "Financial Distress" is above -0.5, the company is considered healthy. Otherwise, it is considered distressed.
#
# In this project, I decided to use regression models to predict the "Financial Distress" value, which then will be converted to the "Health/Distressed" scale.
#
# Notes on raw data:
#
# The columns have arbitrary names (x1, x2, x3 ... x83) as provided, so I have no way of knowing or guessing what each columns represent.
#
# Column 0: Company ID number
# Column 1: Represents a different time the data belongs to.
# Column 82: This data (x80) is categorical according to the data provider.
#
# The above-mentioned columns will be removed during the analysis, as these data will adversely affect the prediction.

# %%
import numpy as np
import pandas as pd
from numpy import arange
from matplotlib import pyplot as plt
from pandas import read_csv
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 50) # set the max_rows to a desired number to see all column properties
pd.set_option('display.max_columns', None) # set this to None to display all columns
figsize = [[],[]]
figsize[0] = 24
figsize[1] = 36
plt.rcParams['figure.figsize'] = figsize

# %%
filename = 'D:\Program_file\Python-File\Financial Distress.csv'
dataset_raw = read_csv(filename)
names = list(dataset_raw.columns.values)
print(dataset_raw.head())
dataset_raw.shape
# Out:
#    Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0        1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1        1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2        1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3        1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4        2     1            1.357300  1.0623  0.107020  0.81460  0.83593
#
#          x5        x6       x7        x8        x9       x10      x11  \
# 0  0.060940  0.188270  0.52510  0.018854  0.182790  0.006449  0.85822
# 1 -0.014080  0.181040  0.62288  0.006423  0.035991  0.001795  0.85152
# 2  0.020476  0.044865  0.43292 -0.081423 -0.765400 -0.054324  0.89314
# 3  0.076037  0.091033  0.67546 -0.018807 -0.107910 -0.065316  0.89581
# 4  0.199960  0.047800  0.74200  0.128030  0.577250  0.094075  0.81549
#
#        x12       x13      x14     x15       x16     x17       x18       x19  \
# 0  2.00580  0.125460   6.9706  4.6512  0.050100  2.1984  0.018265  0.024978
# 1 -0.48644  0.179330   4.5764  3.7521 -0.014011  2.4575  0.027558  0.028804
# 2  0.41220  0.077578  11.8900  2.4884  0.028077  1.3957  0.012595  0.068116
# 3  0.99490  0.141120   6.0862  1.6382  0.093904  2.0588  0.011601  0.094385
# 4  3.01470  0.185400   4.3938  1.6169  0.239210  3.0311  0.006814  0.079346
#
#         x20      x21     x22       x23      x24       x25     x26      x27  \
# 0  0.027264  1.41730  9.5554  0.148720  0.66995   214.760  12.641   6.4607
# 1  0.041102  1.18010  7.2952  0.056026  0.67048    38.242  12.877   5.5506
# 2  0.014847  0.81652  7.1204  0.065220  0.84827  -498.390  13.225  16.2540
# 3  0.014415  0.90391  7.9828  0.125160  0.80478   -75.867  13.305   8.8950
#       x77   x78  x79  x80       x81  x82  x83
# 0  16.000  16.0  0.2   22  0.060390   30   49
# 1  17.000  16.0  0.4   22  0.010636   31   50
# 2  17.000  15.0 -0.2   22 -0.455970   32   51
# 3  17.167  16.0  5.6   22 -0.325390   33   52
# 4  16.000  16.0  0.2   29  1.251000    7   27
# (3672, 86)

# %%
# Removing columns that will not help the model's accuracy
DropColumns = ['Company', 'Time', 'x80']
dataset = dataset_raw.copy()
dataset.drop(DropColumns, axis=1, inplace=True)
print(dataset.head(10))
print(dataset.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-74e51355a05a> in <module>
#       1 # Removing columns that will not help the model's accuracy
#       2 DropColumns = ['Company', 'Time', 'x80']
# ----> 3 dataset = dataset_raw.copy()
#       4 dataset.drop(DropColumns, axis=1, inplace=True)
#       5 print(dataset.head(10))
#
# NameError: name 'dataset_raw' is not defined

# %%
# Checking data types
dataset.dtypes
# Out:
# Financial Distress    float64
# x1                    float64
# x2                    float64
# x3                    float64
# x4                    float64
# x5                    float64
# x6                    float64
# x7                    float64
# x8                    float64
# x9                    float64
# x10                   float64
# x11                   float64
# x12                   float64
# x13                   float64
# x14                   float64
# x15                   float64
# x16                   float64
# x17                   float64
# x18                   float64
# x19                   float64
# x20                   float64
# x21                   float64
# x22                   float64
# x23                   float64
# x24                   float64
#                        ...
# x58                   float64
# x59                   float64
# x60                   float64
# x61                   float64
# x62                   float64
# x63                   float64
# x64                   float64
# x65                   float64
# x66                   float64
# x67                   float64
# x68                   float64
# x69                   float64
# x70                   float64
# x71                   float64
# x72                   float64
# x73                   float64
# x74                   float64
# x75                   float64
# x76                   float64
# x77                   float64
# x78                   float64
# x79                   float64
# x81                   float64
# x82                     int64
# x83                     int64
# Length: 83, dtype: object

# %%
# Checking the general summary of each columns
print(dataset.describe())
# Out:
#        Financial Distress           x1           x2           x3  \
# count         3672.000000  3672.000000  3672.000000  3672.000000
# mean             1.040257     1.387820     0.129706     0.615769
# std              2.652227     1.452926     0.120013     0.177904
# min             -8.631700     0.075170    -0.258080     0.016135
# 25%              0.172275     0.952145     0.048701     0.501888
# 50%              0.583805     1.183600     0.107530     0.638690
# 75%              1.351750     1.506475     0.188685     0.749425
# max            128.400000    51.954000     0.749410     0.967900
#
#                  x4           x5           x6           x7             x8  \
# count  3.672000e+03  3672.000000  3672.000000  3672.000000    3672.000000
# mean   8.681599e-01     0.154949     0.106717     0.784031      39.274361
# std    5.719519e-01     0.124904     0.210555     1.033606    4305.688039
# min    5.350000e-07    -0.269790    -0.627750     0.035160 -145000.000000
# 25%    5.525575e-01     0.070001    -0.027754     0.436003       0.056185
# 50%    7.752450e-01     0.131830     0.104325     0.641875       0.135585
# 75%    1.039000e+00     0.219570     0.231230     0.896773       0.273423
# max    6.835600e+00     0.858540     0.929550    38.836000  209000.000000
#
#                 x9          x10          x11           x12          x13  \
# count  3672.000000  3672.000000  3672.000000  3.672000e+03  3672.000000
# mean      0.332610     0.136263     0.638835  1.252730e+05     0.384230
# std       0.346135     0.138978     0.201986  1.468207e+06     0.177904
# min      -3.611200    -0.318660     0.021491 -2.620000e+06     0.032101
# min     -21.411000   -21.907000    15.916000    10.300000   7941.800000
# 25%      -9.302000     2.656600    23.905000    10.500000   9042.500000
# 50%       1.344500    28.286000    28.184000    11.300000   9667.300000
# 75%       5.826700    57.368000    30.245000    12.200000  26059.000000
# max      18.770000   124.760000    39.432000    13.850000  34501.000000
#
#                x69          x70          x71          x72          x73  \
# count  3672.000000  3672.000000  3672.000000  3672.000000  3672.000000
# mean     21.472377    17.863013    23.301360     1.923501    30.407166
# std      97.191938     7.119361    17.834175     1.469196     3.714512
# min     -58.122000    10.400000   -10.665000     0.000000    22.000000
# 25%     -25.841000    11.900000    10.131000     0.500000    28.000000
# 50%       0.189600    15.600000    22.571000     2.000000    30.000000
# 75%      14.529000    21.500000    36.030000     4.000000    33.000000
# max     364.950000    34.700000    61.476000     4.000000    36.750000
#
#                x74          x75          x76          x77          x78  \
# count  3672.000000  3672.000000  3672.000000  3672.000000  3672.000000
# mean     86.839822    91.920506    89.115908    17.780855    15.198708
# std      16.706209    64.656504    64.349382     2.040152     2.828648
# min      54.806000    24.318000    23.776000    15.250000    12.000000
# 25%      79.951000    39.800000    38.377000    16.000000    13.000000
# 50%      90.000000    66.120000    59.471000    17.000000    14.500000
# 75%      93.883000   130.500000   132.400000    20.000000    16.000000
# max     120.870000   227.500000   214.500000    22.000000    22.000000
#
#                x79          x81          x82          x83
# count  3672.000000  3672.000000  3672.000000  3672.000000
# mean     -2.664305     1.100488    13.122277    33.044935
# std       8.192663     2.666733     9.465907    13.714563
# min     -20.200000    -0.499220     1.000000     2.000000
# 25%      -7.000000     0.189912     6.000000    21.000000
# 50%       0.200000     0.594765    11.000000    34.000000
# 75%       2.100000     1.355050    17.000000    44.000000
# max       8.600000   128.400000    49.000000    74.000000

# %%
# Visualizing the data distribution
figsize[0] = 24
figsize[1] = 36
plt.rcParams['figure.figsize'] = figsize
dataset.hist(sharex=False, sharey=False, xlabelsize=12, ylabelsize=12)
plt.show()

# %%
# Another data distribution visualization
dataset.plot(kind='box', subplots=True, layout=(23,4), sharex=False, sharey=False, fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-577873257c28> in <module>
#       1 # Another data distribution visualization
# ----> 2 dataset.plot(kind='box', subplots=True, layout=(23,4), sharex=False, sharey=False, fontsize=12)
#       3 plt.show()
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# The target (Financial Distress) has one outlier. It will be interesting to compare the models if the outlier is included in or excluded from the training set.

# %%
# Visualizing the correlations
figsize[0] = 100
figsize[1] = 70
plt.rcParams['figure.figsize'] = figsize
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(dataset.corr(), vmin=-1, vmax=1, interpolation='none')
fig.colorbar(cax)
ticks = np.arange(0,86,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %%
# Splitting the dataset into validation set (30% [a requirement by the stakeholder]
array = dataset.values
X = array[:, 1:82]
Y = array[:, 0]
validation_size = 0.30
seed = 3
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
num_folds = 10
scoring = 'neg_mean_squared_error'

# %%
# Initial test to identify high performing algorithms
models = []
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('SVR', SVR()))

# %%
InitialResults = []
InitialNames = []
for name, model in models:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    InitialResults.append(cv_results)
    InitialNames.append(name)
    message = '{0}: {1} ({2})'.format(name, cv_results.mean(), cv_results.std())
    print(message)
# Out:
# D:\Anaconda2_5_Python2_7\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# LASSO: -1.66751081142 (0.495198973976)
# EN: -1.66022726931 (0.501345619993)
# KNN: -1.75718650254 (0.544106880085)
# CART: -2.94603014949 (1.1399490512)
# SVR: -2.82339485597 (0.694716813613)

# %% [markdown]
# I get convergence problems, most likely due to the unscaled data. Will scale the data to see how much improvements I can get.

# %%
# Visualizing the results
figsize[0] = 18
figsize[1] = 12
plt.rcParams['figure.figsize'] = figsize
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(InitialResults)
ax.set_xticklabels(InitialNames)
plt.show()

# %%
# Standardizing the data
pipelines = []
# pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()), ('LR', LinearRegression())])))
pipelines.append(('ScaledLASSO', Pipeline([('Scaler', StandardScaler()), ('LASSO', Lasso())])))
pipelines.append(('ScaledEN', Pipeline([('Scaler', StandardScaler()), ('EN', ElasticNet())])))
pipelines.append(('ScaledKNN', Pipeline([('Scaler', StandardScaler()), ('CART', KNeighborsRegressor())])))
pipelines.append(('ScaledCART', Pipeline([('ScaledCART', StandardScaler()), ('CART', DecisionTreeRegressor())])))
pipelines.append(('ScaledSVR', Pipeline([('Scaler', StandardScaler()), ('SVR', SVR())])))
ScaledResults = []
ScaledNames = []
for name, model in pipelines:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    ScaledResults.append(cv_results)
    ScaledNames.append(name)
    message = '{0}: {1} ({2})'.format(name, cv_results.mean(), cv_results.std())
    print(message)
# Out:
# ScaledLASSO: -2.5089519217 (0.670830366276)
# ScaledEN: -1.89617476631 (0.572375735565)
# ScaledKNN: -1.61707840886 (0.621153633389)
# ScaledCART: -2.95173823093 (1.31226125646)
# ScaledSVR: -1.45432564638 (0.591207516846)

# %%
# Visualizing the results from the standardized dataset
fig = plt.figure()
fig.suptitle('Scaled Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(ScaledResults)
ax.set_xticklabels(ScaledNames)
plt.show()

# %%
# Ensemble methods
ensembles = []
ensembles.append(('ScaledAB', Pipeline([('Scaler', StandardScaler()), ('AB', AdaBoostRegressor())])))
ensembles.append(('ScaledGBM', Pipeline([('Scaler', StandardScaler()), ('GBM', GradientBoostingRegressor())])))
ensembles.append(('ScaledRF', Pipeline([('Scaler', StandardScaler()), ('RF', RandomForestRegressor())])))
ensembles.append(('ScaledET', Pipeline([('Scaler', StandardScaler()), ('ET', ExtraTreesRegressor())])))

EnsemblesResults = []
EnsemblesNames = []
for name, model in ensembles:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    EnsemblesResults.append(cv_results)
    EnsemblesNames.append(name)
    message = '{0}: {1} ({2})'.format(name, cv_results.mean(), cv_results.std())
    print(message)
# Out:
# ScaledAB: -1.67699002577 (0.643104606947)
# ScaledGBM: -1.51495314063 (0.520324444254)
# ScaledRF: -1.65698020588 (0.548433728383)
# ScaledET: -1.48653693619 (0.565184975648)

# %%
# Visualize the results from the ensemble algorithms
fig = plt.figure()
fig.suptitle('Scaled Ensemble Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(EnsemblesResults)
ax.set_xticklabels(EnsemblesNames)
plt.show()

# %%
# Scaling the data for optimization
scaler = StandardScaler().fit(X_train)
rescaledX_train = scaler.transform(X_train)

# %% [markdown]
# Gradient boosting regressor outperformed others by a significant margin. Will optimize the parameters.

# %%
# Tuning parameters for GBR. Initially only one parameter will be optimized. The results from here will be used to narrow down the search space. 
model = GradientBoostingRegressor()
max_depth = [2, 4, 6, 8, 10, 15, 20, 30, 40, 50, 60, 70, 80]
min_samples_split = [2, 4, 6, 8, 10, 15, 20, 30, 40, 50, 60, 70, 80]
min_samples_leaf = [2, 4, 6, 8, 10, 15, 20, 30, 40, 50, 60, 70, 80]
max_leaf_nodes = [2, 4, 6, 8, 10, 15, 20, 30, 40, 50, 60, 70, 80]
param_grid = dict(max_depth = max_depth)
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(rescaledX_train, Y_train)
print('max_depth Best: {0} using {1}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with :{2}'.format(mean, stdev, param))
print('\n')
param_grid = dict(min_samples_split = min_samples_split)
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(rescaledX_train, Y_train)
print('min_samples_split Best: {0} using {1}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with :{2}'.format(mean, stdev, param))
print('\n')
param_grid = dict(min_samples_leaf = min_samples_leaf)
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(rescaledX_train, Y_train)
print('min_samples_leaf Best: {0} using {1}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with :{2}'.format(mean, stdev, param))
min_samples_leaf = min_samples_leaf
print('\n')
param_grid = dict(max_leaf_nodes = max_leaf_nodes)
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(rescaledX_train, Y_train)
print('max_leaf_nodes Best: {0} using {1}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with :{2}'.format(mean, stdev, param))
min_samples_leaf = min_samples_leaf
# Out:
# max_depth Best: -1.41365849335 using {'max_depth': 2}
# -1.41365849335 (0.553085305635) with :{'max_depth': 2}
# -1.65387847505 (0.542687117706) with :{'max_depth': 4}
# -1.63501095968 (0.620120471486) with :{'max_depth': 6}
# -1.71064687659 (0.727955548352) with :{'max_depth': 8}
# -1.96079328674 (0.899861695019) with :{'max_depth': 10}
# -2.40514706998 (1.16642876871) with :{'max_depth': 15}
# -2.71934501514 (1.22824774987) with :{'max_depth': 20}
# -2.7859360391 (1.20596769825) with :{'max_depth': 30}
# -2.78351182553 (1.23821615868) with :{'max_depth': 40}
# -2.81438049746 (1.28989907245) with :{'max_depth': 50}
# -2.82165360381 (1.24337908631) with :{'max_depth': 60}
# -2.80131293939 (1.20926645246) with :{'max_depth': 70}
# -2.82876312398 (1.27143596677) with :{'max_depth': 80}
#
#
# min_samples_split Best: -1.47046326721 using {'min_samples_split': 40}
# -1.50939950138 (0.543098951178) with :{'min_samples_split': 2}
# -1.47755194856 (0.534695812582) with :{'min_samples_split': 4}
# -1.50953204207 (0.538102213237) with :{'min_samples_split': 6}
# -1.47741318828 (0.566896290852) with :{'min_samples_split': 8}
# -1.52856386306 (0.553292231623) with :{'min_samples_split': 10}
# -1.49451963173 (0.526216305563) with :{'min_samples_split': 15}
# -1.53483113481 (0.544346795363) with :{'min_samples_split': 20}
# -1.47652898757 (0.534876283058) with :{'min_samples_split': 30}
# -1.47046326721 (0.54893978335) with :{'min_samples_split': 40}
# -1.48203141178 (0.559369315356) with :{'min_samples_split': 50}
# -1.5005002851 (0.585462888284) with :{'min_samples_split': 60}
# -1.51504336817 (0.600168345017) with :{'min_samples_split': 70}
# -1.50192281552 (0.576717814101) with :{'min_samples_split': 80}
#
#
# min_samples_leaf Best: -1.33070640343 using {'min_samples_leaf': 40}
# -1.40680056306 (0.505800298099) with :{'min_samples_leaf': 2}
# -1.35409005278 (0.512716280344) with :{'min_samples_leaf': 4}
# -1.37378377274 (0.509148818883) with :{'min_samples_leaf': 6}
# -1.4214814052 (0.518529736396) with :{'min_samples_leaf': 8}
# -1.40147451733 (0.511522463269) with :{'min_samples_leaf': 10}
# -1.37793814376 (0.522604682169) with :{'min_samples_leaf': 15}
# -1.40210888314 (0.516714634981) with :{'min_samples_leaf': 20}
# -1.35152455171 (0.524243983665) with :{'min_samples_leaf': 30}
# -1.33070640343 (0.490573866617) with :{'min_samples_leaf': 40}
# -1.34009312064 (0.501060042541) with :{'min_samples_leaf': 50}
# -1.35908614868 (0.520630778694) with :{'min_samples_leaf': 60}
# -1.34776371518 (0.513611411213) with :{'min_samples_leaf': 70}
# -1.35481935214 (0.518447005303) with :{'min_samples_leaf': 80}
#
#
# max_leaf_nodes Best: -1.37817480169 using {'max_leaf_nodes': 2}
# -1.37817480169 (0.542192811933) with :{'max_leaf_nodes': 2}
# -1.45901542877 (0.503184518656) with :{'max_leaf_nodes': 4}
# -1.50501103521 (0.533846248488) with :{'max_leaf_nodes': 6}
# -1.60558259236 (0.613781146137) with :{'max_leaf_nodes': 8}
# -1.61356527722 (0.578757873412) with :{'max_leaf_nodes': 10}
# -1.59833389239 (0.576989560661) with :{'max_leaf_nodes': 15}
# -1.66508160685 (0.516385025977) with :{'max_leaf_nodes': 20}
# -1.65140236148 (0.567273452874) with :{'max_leaf_nodes': 30}
# -1.6508825706 (0.568185003111) with :{'max_leaf_nodes': 40}
# -1.61838667623 (0.557811453654) with :{'max_leaf_nodes': 50}
# -1.62268375758 (0.575451503735) with :{'max_leaf_nodes': 60}
# -1.64309666226 (0.533589086018) with :{'max_leaf_nodes': 70}
# -1.64237619231 (0.550025317515) with :{'max_leaf_nodes': 80}

# %%
# Multi-parameter grid search
max_depth = [2, 4, 6, 8, 10]
min_samples_leaf = [20, 30, 40, 50, 60]
max_leaf_nodes = [2, 4, 6, 8, 10]
param_grid = dict(max_depth = max_depth, min_samples_leaf = min_samples_leaf, max_leaf_nodes = max_leaf_nodes)
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(rescaledX_train, Y_train)
print('Best: {0} using {1}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with :{2}'.format(mean, stdev, param))
# Out:
# Best: -1.30960558043 using {'max_leaf_nodes': 8, 'max_depth': 4, 'min_samples_leaf': 40}
# -1.38183602187 (0.52703664633) with :{'max_leaf_nodes': 2, 'max_depth': 2, 'min_samples_leaf': 20}
# -1.37762416747 (0.534536585802) with :{'max_leaf_nodes': 2, 'max_depth': 2, 'min_samples_leaf': 30}
# -1.36323481191 (0.528250622579) with :{'max_leaf_nodes': 2, 'max_depth': 2, 'min_samples_leaf': 40}
# -1.37325514156 (0.525281345915) with :{'max_leaf_nodes': 2, 'max_depth': 2, 'min_samples_leaf': 50}
# -1.40765659762 (0.548771999162) with :{'max_leaf_nodes': 2, 'max_depth': 2, 'min_samples_leaf': 60}
# -1.36868782556 (0.505695605828) with :{'max_leaf_nodes': 4, 'max_depth': 2, 'min_samples_leaf': 20}
# -1.34703656083 (0.525781738524) with :{'max_leaf_nodes': 4, 'max_depth': 2, 'min_samples_leaf': 30}
# -1.31934729494 (0.509222698106) with :{'max_leaf_nodes': 4, 'max_depth': 2, 'min_samples_leaf': 40}
# -1.32975749129 (0.510406227757) with :{'max_leaf_nodes': 4, 'max_depth': 2, 'min_samples_leaf': 50}
# -1.3474799624 (0.533652276845) with :{'max_leaf_nodes': 4, 'max_depth': 2, 'min_samples_leaf': 60}
# -1.3879182157 (0.500617735641) with :{'max_leaf_nodes': 6, 'max_depth': 2, 'min_samples_leaf': 20}
# -1.35870265501 (0.531323800658) with :{'max_leaf_nodes': 6, 'max_depth': 2, 'min_samples_leaf': 30}
# -1.33367963125 (0.505663906744) with :{'max_leaf_nodes': 6, 'max_depth': 2, 'min_samples_leaf': 40}
# -1.34882683298 (0.507090399015) with :{'max_leaf_nodes': 6, 'max_depth': 2, 'min_samples_leaf': 50}
# -1.36015351637 (0.523162695149) with :{'max_leaf_nodes': 6, 'max_depth': 2, 'min_samples_leaf': 60}
# -1.40239418723 (0.517271584487) with :{'max_leaf_nodes': 8, 'max_depth': 2, 'min_samples_leaf': 20}
# -1.35150962273 (0.524168712582) with :{'max_leaf_nodes': 8, 'max_depth': 2, 'min_samples_leaf': 30}
# -1.33070479512 (0.490579882785) with :{'max_leaf_nodes': 8, 'max_depth': 2, 'min_samples_leaf': 40}
# -1.3401471046 (0.500987575358) with :{'max_leaf_nodes': 8, 'max_depth': 2, 'min_samples_leaf': 50}
# -1.3590469804 (0.520681500975) with :{'max_leaf_nodes': 8, 'max_depth': 2, 'min_samples_leaf': 60}
# -1.40209316333 (0.516770273422) with :{'max_leaf_nodes': 10, 'max_depth': 2, 'min_samples_leaf': 20}
# -1.35169625797 (0.524538440944) with :{'max_leaf_nodes': 10, 'max_depth': 2, 'min_samples_leaf': 30}
# -1.33075119756 (0.490530450059) with :{'max_leaf_nodes': 10, 'max_depth': 2, 'min_samples_leaf': 40}
# -1.34012276034 (0.501006364228) with :{'max_leaf_nodes': 10, 'max_depth': 2, 'min_samples_leaf': 50}
# -1.35907473636 (0.520638126808) with :{'max_leaf_nodes': 10, 'max_depth': 2, 'min_samples_leaf': 60}
# -1.38183602187 (0.52703664633) with :{'max_leaf_nodes': 2, 'max_depth': 4, 'min_samples_leaf': 20}
# -1.37762416747 (0.534536585802) with :{'max_leaf_nodes': 2, 'max_depth': 4, 'min_samples_leaf': 30}
# -1.36323481191 (0.528250622579) with :{'max_leaf_nodes': 2, 'max_depth': 4, 'min_samples_leaf': 40}
# -1.37326568659 (0.525282747915) with :{'max_leaf_nodes': 2, 'max_depth': 4, 'min_samples_leaf': 50}
# -1.40765246012 (0.548770873744) with :{'max_leaf_nodes': 2, 'max_depth': 4, 'min_samples_leaf': 60}
# -1.36868782556 (0.505695605828) with :{'max_leaf_nodes': 4, 'max_depth': 4, 'min_samples_leaf': 20}
# -1.34706507487 (0.525789301619) with :{'max_leaf_nodes': 4, 'max_depth': 4, 'min_samples_leaf': 30}
# -1.31934729494 (0.509222698106) with :{'max_leaf_nodes': 4, 'max_depth': 4, 'min_samples_leaf': 40}
# -1.32975749129 (0.510406227757) with :{'max_leaf_nodes': 4, 'max_depth': 4, 'min_samples_leaf': 50}
# -1.34747110707 (0.533650978327) with :{'max_leaf_nodes': 4, 'max_depth': 4, 'min_samples_leaf': 60}
# -1.4003589605 (0.508352676377) with :{'max_leaf_nodes': 6, 'max_depth': 4, 'min_samples_leaf': 20}
# -1.34751414987 (0.519590676094) with :{'max_leaf_nodes': 6, 'max_depth': 4, 'min_samples_leaf': 30}
# -1.33132893476 (0.491715141505) with :{'max_leaf_nodes': 6, 'max_depth': 4, 'min_samples_leaf': 40}
# -1.33773968124 (0.499323992496) with :{'max_leaf_nodes': 6, 'max_depth': 4, 'min_samples_leaf': 50}
# -1.35879740933 (0.504961613982) with :{'max_leaf_nodes': 6, 'max_depth': 4, 'min_samples_leaf': 60}
# -1.40268130857 (0.510596101129) with :{'max_leaf_nodes': 8, 'max_depth': 4, 'min_samples_leaf': 20}
# -1.32289578117 (0.479642372002) with :{'max_leaf_nodes': 8, 'max_depth': 4, 'min_samples_leaf': 30}
# -1.30960558043 (0.48728882854) with :{'max_leaf_nodes': 8, 'max_depth': 4, 'min_samples_leaf': 40}
# -1.32783424462 (0.490335057202) with :{'max_leaf_nodes': 8, 'max_depth': 4, 'min_samples_leaf': 50}
# -1.33821518295 (0.520248987347) with :{'max_leaf_nodes': 8, 'max_depth': 4, 'min_samples_leaf': 60}
# -1.38634367151 (0.503013332697) with :{'max_leaf_nodes': 10, 'max_depth': 4, 'min_samples_leaf': 20}
# -1.35275626983 (0.509169988424) with :{'max_leaf_nodes': 10, 'max_depth': 4, 'min_samples_leaf': 30}
# -1.32420085045 (0.483189021322) with :{'max_leaf_nodes': 10, 'max_depth': 4, 'min_samples_leaf': 40}
# -1.3319193423 (0.47672820236) with :{'max_leaf_nodes': 10, 'max_depth': 4, 'min_samples_leaf': 50}
# -1.35976705385 (0.510955018667) with :{'max_leaf_nodes': 10, 'max_depth': 4, 'min_samples_leaf': 60}
# -1.38183602187 (0.52703664633) with :{'max_leaf_nodes': 2, 'max_depth': 6, 'min_samples_leaf': 20}
# -1.37762416747 (0.534536585802) with :{'max_leaf_nodes': 2, 'max_depth': 6, 'min_samples_leaf': 30}
# -1.36322174836 (0.528249068121) with :{'max_leaf_nodes': 2, 'max_depth': 6, 'min_samples_leaf': 40}
# -1.37325514156 (0.525281345915) with :{'max_leaf_nodes': 2, 'max_depth': 6, 'min_samples_leaf': 50}
# -1.40765837654 (0.54877248312) with :{'max_leaf_nodes': 2, 'max_depth': 6, 'min_samples_leaf': 60}
# -1.36866920205 (0.505719055902) with :{'max_leaf_nodes': 4, 'max_depth': 6, 'min_samples_leaf': 20}
# -1.34711219872 (0.525752579306) with :{'max_leaf_nodes': 4, 'max_depth': 6, 'min_samples_leaf': 30}
# -1.31929826995 (0.50927916956) with :{'max_leaf_nodes': 4, 'max_depth': 6, 'min_samples_leaf': 40}
# -1.32976595243 (0.510403055693) with :{'max_leaf_nodes': 4, 'max_depth': 6, 'min_samples_leaf': 50}
# -1.3474676816 (0.533653886709) with :{'max_leaf_nodes': 4, 'max_depth': 6, 'min_samples_leaf': 60}
# -1.4000521922 (0.508564978043) with :{'max_leaf_nodes': 6, 'max_depth': 6, 'min_samples_leaf': 20}
# -1.34750773345 (0.519595811137) with :{'max_leaf_nodes': 6, 'max_depth': 6, 'min_samples_leaf': 30}
# -1.33137746649 (0.491655250734) with :{'max_leaf_nodes': 6, 'max_depth': 6, 'min_samples_leaf': 40}
# -1.33773313858 (0.499319856732) with :{'max_leaf_nodes': 6, 'max_depth': 6, 'min_samples_leaf': 50}
# -1.35882462664 (0.504935825386) with :{'max_leaf_nodes': 6, 'max_depth': 6, 'min_samples_leaf': 60}
# -1.39698459302 (0.49009357373) with :{'max_leaf_nodes': 8, 'max_depth': 6, 'min_samples_leaf': 20}
# -1.33925941604 (0.485983677275) with :{'max_leaf_nodes': 8, 'max_depth': 6, 'min_samples_leaf': 30}
# -1.31330532801 (0.491411535574) with :{'max_leaf_nodes': 8, 'max_depth': 6, 'min_samples_leaf': 40}
# -1.34284771878 (0.481196701559) with :{'max_leaf_nodes': 8, 'max_depth': 6, 'min_samples_leaf': 50}
# -1.34991695034 (0.504833935823) with :{'max_leaf_nodes': 8, 'max_depth': 6, 'min_samples_leaf': 60}
# -1.39292293159 (0.490465011493) with :{'max_leaf_nodes': 10, 'max_depth': 6, 'min_samples_leaf': 20}
# -1.32191683483 (0.502315815629) with :{'max_leaf_nodes': 10, 'max_depth': 6, 'min_samples_leaf': 30}
# -1.31266352371 (0.484612287189) with :{'max_leaf_nodes': 10, 'max_depth': 6, 'min_samples_leaf': 40}
# -1.32597420728 (0.477230609808) with :{'max_leaf_nodes': 10, 'max_depth': 6, 'min_samples_leaf': 50}
# -1.34968649242 (0.520634437552) with :{'max_leaf_nodes': 10, 'max_depth': 6, 'min_samples_leaf': 60}
# -1.38183602187 (0.52703664633) with :{'max_leaf_nodes': 2, 'max_depth': 8, 'min_samples_leaf': 20}
# -1.37762416747 (0.534536585802) with :{'max_leaf_nodes': 2, 'max_depth': 8, 'min_samples_leaf': 30}
# -1.36323481191 (0.528250622579) with :{'max_leaf_nodes': 2, 'max_depth': 8, 'min_samples_leaf': 40}
# -1.37324834098 (0.525280442761) with :{'max_leaf_nodes': 2, 'max_depth': 8, 'min_samples_leaf': 50}
# -1.40766243795 (0.548773588229) with :{'max_leaf_nodes': 2, 'max_depth': 8, 'min_samples_leaf': 60}
# -1.36868782556 (0.505695605828) with :{'max_leaf_nodes': 4, 'max_depth': 8, 'min_samples_leaf': 20}
# -1.34711560504 (0.525753483262) with :{'max_leaf_nodes': 4, 'max_depth': 8, 'min_samples_leaf': 30}
# -1.3192989347 (0.509279273515) with :{'max_leaf_nodes': 4, 'max_depth': 8, 'min_samples_leaf': 40}
# -1.32976069446 (0.510402486725) with :{'max_leaf_nodes': 4, 'max_depth': 8, 'min_samples_leaf': 50}
# -1.34747110707 (0.533650978327) with :{'max_leaf_nodes': 4, 'max_depth': 8, 'min_samples_leaf': 60}
# -1.40002334923 (0.508549974341) with :{'max_leaf_nodes': 6, 'max_depth': 8, 'min_samples_leaf': 20}
# -1.34766006884 (0.519828809478) with :{'max_leaf_nodes': 6, 'max_depth': 8, 'min_samples_leaf': 30}
# -1.33138328673 (0.491652195236) with :{'max_leaf_nodes': 6, 'max_depth': 8, 'min_samples_leaf': 40}
# -1.3377387885 (0.49931570675) with :{'max_leaf_nodes': 6, 'max_depth': 8, 'min_samples_leaf': 50}
# -1.35881426274 (0.504948466908) with :{'max_leaf_nodes': 6, 'max_depth': 8, 'min_samples_leaf': 60}
# -1.39721475485 (0.48999633547) with :{'max_leaf_nodes': 8, 'max_depth': 8, 'min_samples_leaf': 20}
# -1.33892906147 (0.485298306878) with :{'max_leaf_nodes': 8, 'max_depth': 8, 'min_samples_leaf': 30}
# -1.31330594153 (0.49141114537) with :{'max_leaf_nodes': 8, 'max_depth': 8, 'min_samples_leaf': 40}
# -1.3427987815 (0.481152517516) with :{'max_leaf_nodes': 8, 'max_depth': 8, 'min_samples_leaf': 50}
# -1.34983712247 (0.504833060293) with :{'max_leaf_nodes': 8, 'max_depth': 8, 'min_samples_leaf': 60}
# -1.38968068509 (0.49024710464) with :{'max_leaf_nodes': 10, 'max_depth': 8, 'min_samples_leaf': 20}
# -1.32917392512 (0.497569026722) with :{'max_leaf_nodes': 10, 'max_depth': 8, 'min_samples_leaf': 30}
# -1.3132750848 (0.481867497368) with :{'max_leaf_nodes': 10, 'max_depth': 8, 'min_samples_leaf': 40}
# -1.32389087118 (0.480556082568) with :{'max_leaf_nodes': 10, 'max_depth': 8, 'min_samples_leaf': 50}
# -1.35059865898 (0.509115419645) with :{'max_leaf_nodes': 10, 'max_depth': 8, 'min_samples_leaf': 60}
# -1.38183602187 (0.52703664633) with :{'max_leaf_nodes': 2, 'max_depth': 10, 'min_samples_leaf': 20}
# -1.37762416747 (0.534536585802) with :{'max_leaf_nodes': 2, 'max_depth': 10, 'min_samples_leaf': 30}
# -1.36323481191 (0.528250622579) with :{'max_leaf_nodes': 2, 'max_depth': 10, 'min_samples_leaf': 40}
# -1.37326261498 (0.525282339336) with :{'max_leaf_nodes': 2, 'max_depth': 10, 'min_samples_leaf': 50}
# -1.40765659762 (0.548771999162) with :{'max_leaf_nodes': 2, 'max_depth': 10, 'min_samples_leaf': 60}
# -1.36867031034 (0.505717660243) with :{'max_leaf_nodes': 4, 'max_depth': 10, 'min_samples_leaf': 20}
# -1.34708709099 (0.525745922393) with :{'max_leaf_nodes': 4, 'max_depth': 10, 'min_samples_leaf': 30}
# -1.31934729494 (0.509222698106) with :{'max_leaf_nodes': 4, 'max_depth': 10, 'min_samples_leaf': 40}
# -1.32975749129 (0.510406227757) with :{'max_leaf_nodes': 4, 'max_depth': 10, 'min_samples_leaf': 50}
# -1.3474799624 (0.533652276845) with :{'max_leaf_nodes': 4, 'max_depth': 10, 'min_samples_leaf': 60}
# -1.3999584435 (0.508610315756) with :{'max_leaf_nodes': 6, 'max_depth': 10, 'min_samples_leaf': 20}
# -1.34751266217 (0.51959714722) with :{'max_leaf_nodes': 6, 'max_depth': 10, 'min_samples_leaf': 30}
# -1.33139296335 (0.491645210926) with :{'max_leaf_nodes': 6, 'max_depth': 10, 'min_samples_leaf': 40}
# -1.33776515005 (0.499306749401) with :{'max_leaf_nodes': 6, 'max_depth': 10, 'min_samples_leaf': 50}
# -1.35873971431 (0.504995207932) with :{'max_leaf_nodes': 6, 'max_depth': 10, 'min_samples_leaf': 60}
# -1.39715537352 (0.490022589699) with :{'max_leaf_nodes': 8, 'max_depth': 10, 'min_samples_leaf': 20}
# -1.33918151832 (0.48595902674) with :{'max_leaf_nodes': 8, 'max_depth': 10, 'min_samples_leaf': 30}
# -1.31316572618 (0.491450042171) with :{'max_leaf_nodes': 8, 'max_depth': 10, 'min_samples_leaf': 40}
# -1.34285911923 (0.481182777705) with :{'max_leaf_nodes': 8, 'max_depth': 10, 'min_samples_leaf': 50}
# -1.34989499265 (0.504817195371) with :{'max_leaf_nodes': 8, 'max_depth': 10, 'min_samples_leaf': 60}
# -1.3895381296 (0.490363873177) with :{'max_leaf_nodes': 10, 'max_depth': 10, 'min_samples_leaf': 20}
# -1.32949800053 (0.497770409652) with :{'max_leaf_nodes': 10, 'max_depth': 10, 'min_samples_leaf': 30}
# -1.31317569529 (0.482016664591) with :{'max_leaf_nodes': 10, 'max_depth': 10, 'min_samples_leaf': 40}
# -1.32390532965 (0.480543206075) with :{'max_leaf_nodes': 10, 'max_depth': 10, 'min_samples_leaf': 50}
# -1.35057251698 (0.509156325189) with :{'max_leaf_nodes': 10, 'max_depth': 10, 'min_samples_leaf': 60}

# %%
# Finalizing the model
model = GradientBoostingRegressor(min_samples_split=8, max_depth=4, min_samples_leaf=40)
model.fit(rescaledX_train, Y_train)

# ... and see how the model performs against the validation set
rescaledX_validation = scaler.transform(X_validation)

Predictions = model.predict(rescaledX_validation)

print(mean_squared_error(Y_validation, Predictions))
# Out:
# 14.2100896101

# %% [markdown]
# The error from the validation is considerably worse... The model needs a significant improvement.

# %%
# Converting the Financial Distress values to a "Healthy/Distressed" results
FinalPredictions = []
Validations = []
for i in Predictions:
    if i > -0.5:
        FinalPredictions.append(0)
    else:
        FinalPredictions.append(1)
for i in Y_validation:
    if i > -0.5:
        Validations.append(0)
    else:
        Validations.append(1)

# %%
# Analyzing the performance of the model using a confusion matrix
y_true = pd.Series(Validations)
y_prediction = pd.Series(FinalPredictions)
crsTab = pd.crosstab(y_true, y_prediction, rownames=['True'], colnames=['Predicted'], margins=True)
print(crsTab)
# Out:
# Predicted     0   1   All
# True
# 0          1048  26  1074
# 1            18  10    28
# All        1066  36  1102

# %% [markdown]
# Predictions for the financially distressed companies are not good. This is most-likely due to the unbalanced data. Potential solutions are to use different performance measurement (Precision, Recall, F-score, Kappa, etc.), and/or to resample the dataset to balance (sampling with replacements). Will try resampling to balance the dataset in the future.
